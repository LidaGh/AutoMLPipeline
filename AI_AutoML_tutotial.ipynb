# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
#
# Licensed under the MIT License.

# %% [markdown]
# # Tutorial: Azure Automated Machine Learning

# %% [markdown]
# ## Import packages
# Begin by importing the SDK.

# %%
import azureml.dataprep as dprep
import pandas as pd

# %% [markdown]
# ## Load data
# Load the diabetes and doctors data set

# %%
# !pip install kaggle
# Out:
# Collecting kaggle
#   Downloading https://files.pythonhosted.org/packages/78/3a/64a6447e5faa313b70cb555e21b5a30718c95bcc4902d91784b57fbab737/kaggle-1.5.3.tar.gz (54kB)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\users\lighahre\appdata\local\continuum\miniconda3\envs\py36\lib\site-packages (from kaggle) (1.24.1)
# Requirement already satisfied: six>=1.10 in c:\users\lighahre\appdata\local\continuum\miniconda3\envs\py36\lib\site-packages (from kaggle) (1.12.0)
# Requirement already satisfied: certifi in c:\users\lighahre\appdata\local\continuum\miniconda3\envs\py36\lib\site-packages (from kaggle) (2019.3.9)
# Requirement already satisfied: python-dateutil in c:\users\lighahre\appdata\local\continuum\miniconda3\envs\py36\lib\site-packages (from kaggle) (2.8.0)
# Requirement already satisfied: requests in c:\users\lighahre\appdata\local\continuum\miniconda3\envs\py36\lib\site-packages (from kaggle) (2.21.0)
# Collecting tqdm (from kaggle)
#   Downloading https://files.pythonhosted.org/packages/6c/4b/c38b5144cf167c4f52288517436ccafefe9dc01b8d1c190e18a6b154cd4a/tqdm-4.31.1-py2.py3-none-any.whl (48kB)
# Collecting python-slugify (from kaggle)
#   Downloading https://files.pythonhosted.org/packages/c1/19/c3cf1dc65e89aa999f85a4a3a4924ccac765a6964b405d487b7b7c8bb39f/python-slugify-3.0.2.tar.gz
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\lighahre\appdata\local\continuum\miniconda3\envs\py36\lib\site-packages (from requests->kaggle) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\lighahre\appdata\local\continuum\miniconda3\envs\py36\lib\site-packages (from requests->kaggle) (2.8)
# Collecting text-unidecode==1.2 (from python-slugify->kaggle)
#   Downloading https://files.pythonhosted.org/packages/79/42/d717cc2b4520fb09e45b344b1b0b4e81aa672001dd128c180fabc655c341/text_unidecode-1.2-py2.py3-none-any.whl (77kB)
# Building wheels for collected packages: kaggle, python-slugify
#   Building wheel for kaggle (setup.py): started
#   Building wheel for kaggle (setup.py): finished with status 'done'
#   Stored in directory: C:\Users\lighahre\AppData\Local\pip\Cache\wheels\ee\97\c5\87dcdc9434fe4e632ed5945e31a03703af229db178ef6a00e8
#   Building wheel for python-slugify (setup.py): started
#   Building wheel for python-slugify (setup.py): finished with status 'done'
#   Stored in directory: C:\Users\lighahre\AppData\Local\pip\Cache\wheels\16\7f\c3\6b0582283ad589d68a306da924a78c74546e010d8106b9b3a9
# Successfully built kaggle python-slugify
# Installing collected packages: tqdm, text-unidecode, python-slugify, kaggle
# Successfully installed kaggle-1.5.3 python-slugify-3.0.2 text-unidecode-1.2 tqdm-4.31.1

# %%
kaggle --version #I could not install kaggle on Jupyternotebook to use the API for loading the data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-f413c3c1f729> in <module>()
# ----> 1 kaggle --version
#
# NameError: name 'kaggle' is not defined

# %%
import zipfile
import os.path
import os
zipFilePath = "./KaggleDataSets/"
destDir = "./KaggleDataSets/UnzipData"
# unzip a file
def unzip(zipFilePath, destDir):
    zfile = zipfile.ZipFile(zipFilePath)
    for name in zfile.namelist():
        (dirName, fileName) = os.path.split(name)
        if fileName == '':
            # directory
            newDir = destDir + '/' + dirName
            if not os.path.exists(newDir):
                os.mkdir(newDir)
        else:
            # file
            fd = open(destDir + '/' + name, 'wb')
            fd.write(zfile.read(name))
            fd.close()
    zfile.close()
    
unzip(zipFilePath,destDir)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-1-038cd277ba9f> in <module>()
#      21     zfile.close()
#      22
# ---> 23 unzip(zipFilePath,destDir)
#
# <ipython-input-1-038cd277ba9f> in unzip(zipFilePath, destDir)
#       6 # unzip a file
#       7 def unzip(zipFilePath, destDir):
# ----> 8     zfile = zipfile.ZipFile(zipFilePath)
#       9     for name in zfile.namelist():
#      10         (dirName, fileName) = os.path.split(name)
#
# ~\AppData\Local\Continuum\miniconda3\envs\myenv\lib\zipfile.py in __init__(self, file, mode, compression, allowZip64)
#    1088             while True:
#    1089                 try:
# -> 1090                     self.fp = io.open(file, filemode)
#    1091                 except OSError:
#    1092                     if filemode in modeDict:
#
# PermissionError: [Errno 13] Permission denied: './KaggleDataSets/'

# %%
diabetes = pd.read_csv("diabetes.csv", encoding='cp1252')
doctors = pd.read_csv("doctors.csv", encoding='cp1252')
#b = b.dropna(axis=1)
merged = diabetes.merge(doctors, on='PatientID')
merged.to_csv("output.csv", index=False)

dataset=dprep.auto_read_file("output.csv")
dataset.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-54d58c845777> in <module>()
# ----> 1 diabetes = pd.read_csv("diabetes.csv", encoding='cp1252')
#       2 doctors = pd.read_csv("doctors.csv", encoding='cp1252')
#       3 #b = b.dropna(axis=1)
#       4 merged = diabetes.merge(doctors, on='PatientID')
#       5 merged.to_csv("output.csv", index=False)
#
# NameError: name 'pd' is not defined

# %%
import os
file_path = os.path.join(os.getcwd(), "dflowsdemo.dprep")

dflow_prepared = dataset
package = dprep.Package([dflow_prepared])
package.save(file_path)
# Out:
# Package
#   name: None
#   path: C:\Users\lighahre\OneDrive - Microsoft\Trainings\AutoML_Practice\AutoMLPipeline\dflowsdemo.dprep
#   dataflows: [
#     Dataflow {
#       name: output
#       steps: 4
#     },
#   ]

# %% [markdown]
# ## Import packages
# Import Python packages you need in this tutorial.

# %%
import azureml.core
import pandas as pd
from azureml.core.workspace import Workspace
import logging

# %% [markdown]
# ### Configure workspace
#
# Create a workspace object from the existing workspace. A `Workspace` is a class that accepts your Azure subscription and resource information, and creates a cloud resource to monitor and track your model runs. `Workspace.from_config()` reads the file **aml_config/config.json** and loads the details into an object named `ws`.  `ws` is used throughout the rest of the code in this tutorial.
#
# Once you have a workspace object, specify a name for the experiment and create and register a local directory with the workspace. The history of all runs is recorded under the specified experiment.

# %%
ws = Workspace.from_config()
# choose a name for the run history container in the workspace
experiment_name = 'automated-ml-regression'
# project folder
project_folder = './automated-ml-regression'

import os

output = {}
output['SDK version'] = azureml.core.VERSION
output['Subscription ID'] = ws.subscription_id
output['Workspace'] = ws.name
output['Resource Group'] = ws.resource_group
output['Location'] = ws.location
output['Project Directory'] = project_folder
pd.set_option('display.max_colwidth', -1)
outputDf = pd.DataFrame(data = output, index = [''])
outputDf.T
# Out:
# Warning: Falling back to use azure cli login credentials.
# If you run your code in unattended mode, i.e., where you can't give a user input, then we recommend to use ServicePrincipalAuthentication or MsiAuthentication.
# Please refer to aka.ms/aml-notebook-auth for different authentication mechanisms in azureml-sdk.
# Found the config file in: C:\Users\lighahre\OneDrive - Microsoft\Trainings\AutoML_Practice\AutoMLPipeline\config.json
#
# SDK version        1.0.18
# Subscription ID    20c286f5-1d7a-49dd-b06f-a0a852d9173c
# Workspace          aml_autoML
# Resource Group     AutoML
# Location           eastus2
# Project Directory  ./automated-ml-regression

# %% [markdown]
# ## Explore data
#
# Utilize the data flow object you have previously created. Open and execute the data flow and review the results.

# %%
import azureml.dataprep as dprep

file_path = os.path.join(os.getcwd(), "dflowsdemo.dprep")

package_saved = dprep.Package.open(file_path)
dflow_prepared = package_saved.dataflows[0]
dflow_prepared.get_profile()
# Out:
# ColumnProfile:
#     column_name: PatientID
#     type: FieldType.DECIMAL
#
#     min: 1000038.0
#     max: 1999997.0
#     count: 15000.0
#     missing_count: 0.0
#     not_missing_count: 15000.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 1001441.625
#            1%: 1101704.247593439
#            5%: 1098483.0808080805
#           25%: 1252375.7055823307
#           50%: 1505616.1192090397
#           75%: 1754576.1926238143
#           95%: 1952407.7768627012
#           99%: 1990949.4932126696
#         99.9%: 1999089.334920635
#
#     mean: 1502922.00286666
#     std: 289253.4434711826
#     variance: 83667554559.93663
#     skewness: -0.012275522390474247
#     kurtosis: -1.2047565778864253
#
# ColumnProfile:
#     column_name: Pregnancies
#     type: FieldType.DECIMAL
#
#     min: 0.0
#     max: 14.0
#     count: 15000.0
#     missing_count: 0.0
#     not_missing_count: 15000.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 0.0
#           50%: 2.0
#           75%: 6.0
#           95%: 9.396700585877273
#           99%: 11.707826086956521
#         99.9%: 13.980263157894736
#
#     mean: 3.224533333333337
#     std: 3.3910202078566627
#     variance: 11.499018050092243
#     skewness: 0.8233903465062623
#     kurtosis: -0.507501590139718
#
# ColumnProfile:
#     column_name: PlasmaGlucose
#     type: FieldType.DECIMAL
#
#     min: 44.0
#     max: 192.0
#     count: 15000.0
#     missing_count: 0.0
#     not_missing_count: 15000.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 44.0
#            1%: 69.47987695462706
#            5%: 69.0
#           25%: 83.966171260693
#           50%: 104.51380347593582
#           75%: 129.26690976834573
#           95%: 168.4055258467023
#           99%: 178.8778659611993
#         99.9%: 189.37858851674642
#
#     mean: 107.85686666666672
#     std: 31.98197465181079
#     variance: 1022.846702629068
#     skewness: 0.32480537395003245
#     kurtosis: -0.5440784045185776
#
# ColumnProfile:
#     column_name: DiastolicBloodPressure
#     type: FieldType.DECIMAL
#
#     min: 24.0
#     max: 117.0
#     count: 15000.0
#     missing_count: 0.0
#     not_missing_count: 15000.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 24.375
#            1%: 49.0
#            5%: 49.0
#           25%: 57.738315003927724
#           50%: 72.07151908169351
#           75%: 84.95681310498884
#           95%: 95.88854696280438
#           99%: 104.54136960600373
#         99.9%: 115.3375
#
#     mean: 71.22066666666692
#     std: 16.758716036531577
#     variance: 280.85456319310066
#     skewness: -0.10928638800699551
#     kurtosis: -0.8095978043935759
#
# ColumnProfile:
#     column_name: TricepsThickness
#     type: FieldType.DECIMAL
#
#     min: 7.0
#     max: 93.0
#     count: 15000.0
#     missing_count: 0.0
#     not_missing_count: 15000.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 7.0
#            1%: 9.0
#            5%: 9.0
#           25%: 14.992382617382619
#           50%: 30.497711047145124
#           75%: 41.206630536968426
#           95%: 51.95581014729952
#           99%: 56.078125
#         99.9%: 88.49789915966386
#
#     mean: 28.814000000000085
#     std: 14.555715781923244
#     variance: 211.8688619241294
#     skewness: 0.19775686547395116
#     kurtosis: -0.5968657243262987
#
# ColumnProfile:
#     column_name: SerumInsulin
#     type: FieldType.DECIMAL
#
#     min: 14.0
#     max: 799.0
#     count: 15000.0
#     missing_count: 0.0
#     not_missing_count: 15000.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 14.0
#            1%: 23.781744421906694
#            5%: 23.0
#           25%: 38.379171057253245
#           50%: 83.96457108397406
#           75%: 194.81415168446657
#           95%: 407.1533333333334
#           99%: 649.5568181818181
#         99.9%: 758.1905982905982
#
#     mean: 137.8521333333335
#     std: 133.06825195901362
#     variance: 17707.159679427532
#     skewness: 1.7673248362881535
#     kurtosis: 3.67903344552155
#
# ColumnProfile:
#     column_name: BMI
#     type: FieldType.DECIMAL
#
#     min: 18.20051152
#     max: 56.03462763
#     count: 15000.0
#     missing_count: 0.0
#     not_missing_count: 15000.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 18.214721706888888
#            1%: 19.695440531381582
#            5%: 19.65639742552632
#           25%: 21.26044010579877
#           50%: 31.78574364564554
#           75%: 39.277507771403606
#           95%: 46.99567261054334
#           99%: 51.5814100455
#         99.9%: 55.484277191089745
#
#     mean: 31.509646041017305
#     std: 9.758999734051928
#     variance: 95.23807580922559
#     skewness: 0.19325294966779547
#     kurtosis: -1.2062967880687026
#
# ColumnProfile:
#     column_name: DiabetesPedigree
#     type: FieldType.DECIMAL
#
#     min: 0.078043795
#     max: 2.3015941890000002
#     count: 15000.0
#     missing_count: 0.0
#     not_missing_count: 15000.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 0.07830013237037038
#            1%: 0.10232973563589022
#            5%: 0.10221955814285714
#           25%: 0.13785272037519827
#           50%: 0.20065711910317258
#           75%: 0.6169323055951933
#           95%: 1.138902809163793
#           99%: 1.7330626145398282
#         99.9%: 2.2223207097760684
#
#     mean: 0.3989677489565996
#     std: 0.37794353215407717
#     variance: 0.14284131349709994
#     skewness: 1.675031352815623
#     kurtosis: 2.9431337652377865
#
# ColumnProfile:
#     column_name: Age
#     type: FieldType.DECIMAL
#
#     min: 21.0
#     max: 77.0
#     count: 15000.0
#     missing_count: 0.0
#     not_missing_count: 15000.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 21.0
#            1%: 21.0
#            5%: 21.0
#           25%: 22.0
#           50%: 24.0
#           75%: 35.087118587118574
#           95%: 56.7703081232493
#           99%: 68.15209235209234
#         99.9%: 74.5125
#
#     mean: 30.137733333333355
#     std: 12.08970251588861
#     variance: 146.16090692268338
#     skewness: 1.482935001982875
#     kurtosis: 1.22477190094604
#
# ColumnProfile:
#     column_name: Diabetic
#     type: FieldType.DECIMAL
#
#     min: 0.0
#     max: 1.0
#     count: 15000.0
#     missing_count: 0.0
#     not_missing_count: 15000.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 0.0
#           50%: 0.0
#           75%: 1.0
#           95%: 1.0
#           99%: 1.0
#         99.9%: 1.0
#
#     mean: 0.33333333333333415
#     std: 0.47142023506077585
#     variance: 0.22223703802475714
#     skewness: 0.7070360716869559
#     kurtosis: -1.5001999933333356
#
# ColumnProfile:
#     column_name: Physician
#     type: FieldType.STRING
#
#     min: Aaliyah Briggs
#     max: Zachary Parsons
#     count: 15000.0
#     missing_count: 0.0
#     not_missing_count: 15000.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0

# %% [markdown]
# You prepare the data for the experiment by adding columns to `dflow_X` to be features for our model creation. You define `dflow_y` to be our prediction value; cost.

# %%
dflow_X = dflow_prepared.keep_columns(['PatientID','Pregnancies', 'PlasmaGlucose','DiastolicBloodPressure', 'TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age','Physician'])
dflow_y = dflow_prepared.keep_columns('Diabetic')

# %% [markdown]
# ### Split data into train and test sets
#
# Now you split the data into training and test sets using the `train_test_split` function in the `sklearn` library. This function segregates the data into the x (features) data set for model training and the y (values to predict) data set for testing. The `test_size` parameter determines the percentage of data to allocate to testing. The `random_state` parameter sets a seed to the random generator, so that your train-test splits are always deterministic.

# %%
from sklearn.model_selection import train_test_split


x_df = dflow_X.to_pandas_dataframe()
y_df = dflow_y.to_pandas_dataframe()

x_train, x_test, y_train, y_test = train_test_split(x_df, y_df, test_size=0.2, random_state=223)
# flatten y_train to 1d array
y_train.values.flatten()
# Out:
# array([1., 0., 1., ..., 1., 1., 0.])

# %% [markdown]
# ## Automatically train a model
#
# To automatically train a model:
# 1. Define settings for the experiment run
# 1. Submit the experiment for model tuning
#
#
# ### Define settings for autogeneration and tuning
#
# Define the experiment parameters and models settings for autogeneration and tuning. View the full list of [settings](https://docs.microsoft.com/en-us/azure/machine-learning/service/how-to-configure-auto-train).
#
#
# |Property| Value in this tutorial |Description|
# |----|----|---|
# |**iteration_timeout_minutes**|10|Time limit in minutes for each iteration|
# |**iterations**|30|Number of iterations. In each iteration, the model trains with the data with a specific pipeline|
# |**primary_metric**|spearman_correlation | Metric that you want to optimize.|
# |**preprocess**| True | True enables experiment to perform preprocessing on the input.|
# |**verbosity**| logging.INFO | Controls the level of logging.|
# |**n_cross_validationss**|5|Number of cross validation splits

# %%
automl_settings = {
    "iteration_timeout_minutes" : 1,
    "iterations" : 10,
    "primary_metric" : 'spearman_correlation',
    "preprocess" : True,
    "verbosity" : logging.INFO,
    "n_cross_validations": 5
}

# %%
from azureml.train.automl import AutoMLConfig

# local compute 
automated_ml_config = AutoMLConfig(task = 'regression',
                             debug_log = 'automated_ml_errors.log',
                             path = project_folder,
                             X = x_train.values,
                             y = y_train.values.flatten(),
                             **automl_settings)

# %% [markdown]
# ### Train the automatic regression model
#
# Start the experiment to run locally. Pass the defined `automated_ml_config` object to the experiment, and set the output to `true` to view progress during the experiment.

# %%
from azureml.core.experiment import Experiment
experiment=Experiment(ws, experiment_name)
local_run = experiment.submit(automated_ml_config, show_output=True)
# Out:
# Running on local machine
# Parent Run ID: AutoML_7b286b5c-22d4-403a-9936-665657ae8eb5
# ********************************************************************************************************************
# ITERATION: The iteration being evaluated.
# PIPELINE: A summary description of the pipeline being evaluated.
# SAMPLING %: Percent of the training data to sample.
# DURATION: Time taken for the current iteration.
# METRIC: The result of computing score on the fitted pipeline.
# BEST: The best observed score thus far.
# ********************************************************************************************************************
#
#  ITERATION   PIPELINE                                       SAMPLING %  DURATION      METRIC      BEST
#          0   StandardScalerWrapper RandomForest             100.0000    0:00:37       0.7288    0.7288
#          1   MaxAbsScaler RandomForest                      100.0000    0:01:03       0.7617    0.7617
#          2   StandardScalerWrapper ExtremeRandomTrees       100.0000    0:00:33       0.7466    0.7617
#          3   StandardScalerWrapper LightGBM                 100.0000    0:00:39       0.7644    0.7644
#          4   StandardScalerWrapper RandomForest             100.0000    0:00:33       0.7369    0.7644
#          5   MaxAbsScaler ExtremeRandomTrees                100.0000    0:00:47       0.7596    0.7644
#          6
# WARNING:urllib3.connectionpool:Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', OSError("(10054, 'WSAECONNRESET')",))': /azureml/ExperimentRun/dcid.AutoML_7b286b5c-22d4-403a-9936-665657ae8eb5_6/outputs/model_train.pkl?sv=2018-03-28&sr=b&sig=t5pKdCDGErLLZZv8EPXxkhN4zYRV2BcCTf5rQciQNXA%3D&st=2019-04-25T08%3A35%3A20Z&se=2019-04-26T08%3A45%3A20Z&sp=rcw&comp=block&blockid=TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQSUzRA%3D%3D
# StandardScalerWrapper ExtremeRandomTrees       100.0000    0:01:54       0.7530    0.7644
#          7   MaxAbsScaler DecisionTree                      100.0000    0:00:31       0.7886    0.7886
#          8   MaxAbsScaler ExtremeRandomTrees                100.0000    0:00:47       0.7496    0.7886
#          9   Ensemble                                       100.0000    0:01:19       0.7711    0.7886

# %% [markdown]
# ###  Add a Jupyter widget to see results
#
# Use the Jupyter notebook widget to see a graph and a table of all results.

# %%
from azureml.widgets import RunDetails
RunDetails(local_run).show()
# Out:
# _AutoMLWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', 's…

# %% [markdown]
# ## Retrieve the best model
#
# Select the best pipeline from our iterations. The `get_output` method on `automl_classifier` returns the best run and the fitted model for the last fit invocation. There are overloads on `get_output` that allow you to retrieve the best run and fitted model for any logged metric or a particular iteration.

# %%
best_run, fitted_model = local_run.get_output()
print(best_run)
print(fitted_model)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-98962f203b2e> in <module>()
# ----> 1 best_run, fitted_model = local_run.get_output()
#       2 print(best_run)
#       3 print(fitted_model)
#
# NameError: name 'local_run' is not defined

# %% [markdown]
# ## Register the model
#
# Register the model in your Azure Machine Learning Workspace.

# %%
description = 'Automated Machine Learning Model - Demo 25th April 19'
tags = None
local_run.register_model(description=description, tags=tags)
print(local_run.model_id) # Use this id to deploy the model as a web service in Azure
# Out:
# Registering model AutoML7b286b5c2best
# AutoML7b286b5c2best

# %% [markdown]
# ### Download the model

# %%
from azureml.core.model import Model
import os

model = Model(workspace=ws, name="AutoML7b286b5c2best")
model.download(target_dir="/home/nbuser/library/tutorials/output", exist_ok='true')
# Out:
# '\\home\\nbuser\\library\\tutorials\\output\\model.pkl'

# %% [markdown]
# ### Deploy the model
#
# Use the python SDK to operationalise the model in a docker container

# %%
from azureml.train.automl.automlexplainer import explain_model
import numpy as np
from sklearn.externals import joblib

#model


train_row = pd.DataFrame(x_df,columns=['PatientID','Pregnancies', 'PlasmaGlucose','DiastolicBloodPressure', 'TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age','Physician'])
test_row = pd.DataFrame(y_df,columns =['Diabetes'])

#print(train_row)
shap_values, expected_values, overall_summary, overall_imp, per_class_summary, per_class_imp = \
   explain_model(fitted_model, train_row, test_row)

#print(overall_summary)
#print(overall_imp)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Continuum\miniconda3\envs\myenv\lib\site-packages\azureml\train\automl\automlexplainer.py in explain_model(fitted_model, X_train, X_test, best_run, features, **kwargs)
#      51     try:
# ---> 52         from azureml.explain.model._internal import TabularExplainer
#      53
#
# ModuleNotFoundError: No module named 'azureml.explain'
#
# During handling of the above exception, another exception occurred:
#
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-25-e7805e42be27> in <module>()
#       9
#      10 #print(train_row)
# ---> 11 shap_values, expected_values, overall_summary, overall_imp, per_class_summary, per_class_imp =    explain_model(fitted_model, train_row, test_row)
#      12
#      13 #print(overall_summary)
#
# ~\AppData\Local\Continuum\miniconda3\envs\myenv\lib\site-packages\azureml\train\automl\automlexplainer.py in explain_model(fitted_model, X_train, X_test, best_run, features, **kwargs)
#      89     except ImportError as import_error:
#      90         logger.warning(
# ---> 91             "[RunId:{}]Explain model function meets import error. Error message:{}".format(run_id, import_error)
#      92         )
#      93         raise
#
# UnboundLocalError: local variable 'run_id' referenced before assignment
